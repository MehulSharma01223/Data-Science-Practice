# %%
import pandas as pd

# %%
import matplotlib as plt

# %% [markdown]
# ## Creating Data Frame ##

# %%
# using lists

student_data = [
    [100,80,10],
    [90,70,8.8],
    [120,100,14],
    [180,100,20]
]
pd.DataFrame(student_data,columns=['Iq','marks','package'])
# Out:
#     Iq  marks  package
# 0  100     80     10.0
# 1   90     70      8.8
# 2  120    100     14.0
# 3  180    100     20.0

# %%
# using dicts

student_data = {
   'iq': [100,80,10],
    'marks' :[90,70,8.8],
    'packages' :[120,100,14],\

}
students = pd.DataFrame(student_data)
students
# Out:
#     iq  marks  packages
# 0  100   90.0       120
# 1   80   70.0       100
# 2   10    8.8        14

# %%
# using read.csv
movies = pd.read_csv(r'C:\Users\MAINAK\Desktop\SQl\ds\Python_Pandas\movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv(r'C:\Users\MAINAK\Desktop\SQl\ds\Python_Pandas\ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # DataFrame Attributes and Methods

# %%
# shape
movies.shape
# Out:
# (1629, 18)

# %%
# dtypes
movies.dtypes
# Out:
# title_x                 str
# imdb_id                 str
# poster_path             str
# wiki_link               str
# title_y                 str
# original_title          str
# is_adult              int64
# year_of_release       int64
# runtime                 str
# genres                  str
# imdb_rating         float64
# imdb_votes            int64
# story                   str
# summary                 str
# tagline                 str
# actors                  str
# wins_nominations        str
# release_date            str
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
# values 
students.values
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
# head and tail
movies.head(2)
ipl.tail(4)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# ...

# %%
# sample
movies.sample(7
)
# Out:
#                             title_x    imdb_id  \
# 1429           Footpath (2003 film)  tt0374660
# 526                 Mary Kom (film)  tt3001638
# 686            Life Ki Toh Lag Gayi  tt2327389
# 87                          Aiyaary  tt6774212
# 795                   Mummy Punjabi  tt2066925
# 1085  Jahan Jaaeyega Hamen Paaeyega  tt1236470
# 1238                        Chehraa  tt0449870
#
#                                             poster_path  \
# 1429  https://upload.wikimedia.org/wikipedia/en/thum...
# 526   https://upload.wikimedia.org/wikipedia/en/thum...
# 686   https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 795   https://upload.wikimedia.org/wikipedia/en/4/45...
# 1085  https://upload.wikimedia.org/wikipedia/en/2/20...
# 1238  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1429  https://en.wikipedia.org/wiki/Footpath_(2003_f...
# ...

# %%
# info
movies.info(5)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
# describe
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# is null
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies.notnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0        True     True         True       True     True            True
# 1        True     True        False       True     True            True
# 2        True     True         True       True     True            True
# 3        True     True         True       True     True            True
# 4        True     True        False       True     True            True
# ...       ...      ...          ...        ...      ...             ...
# 1624     True     True         True       True     True            True
# 1625     True     True         True       True     True            True
# 1626     True     True        False       True     True            True
# 1627     True     True         True       True     True            True
# 1628     True     True         True       True     True            True
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
# duplicates
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
#rename
students.rename(columns={'marks': 'percent','packages':'lpa'})
# Out:
#     iq  percent  lpa
# 0  100     90.0  120
# 1   80     70.0  100
# 2   10      8.8   14

# %% [markdown]
# ## Math Modules

# %%
# sum -> axis argument'
movies.sum()
# Out:
# title_x             Uri: The Surgical StrikeBattalion 609The Accid...
# imdb_id             tt8291224tt9472208tt6986710tt8108208tt6028796t...
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y             Uri: The Surgical StrikeBattalion 609The Accid...
# original_title      Uri: The Surgical StrikeBattalion 609The Accid...
# is_adult                                                            0
# year_of_release                                               3274720
# runtime             1381311121211029710910414812013415314313014311...
# genres              Action|Drama|WarWarBiography|DramaCrime|DramaD...
# imdb_rating                                                    9053.1
# imdb_votes                                                    8770965
# story               Divided over five chapters  the film chronicle...
# ...

# %%
# students.sum(axis = 1)

# %%
students
# Out:
#     iq  marks  packages
# 0  100   90.0       120
# 1   80   70.0       100
# 2   10    8.8        14

# %%
students.mean(axis= 1)
# Out:
# 0    103.333333
# 1     83.333333
# 2     10.933333
# dtype: float64

# %%
students.std()
# Out:
# iq          47.258156
# marks       42.306186
# packages    56.320511
# dtype: float64

# %%
students.var()
# Out:
# iq          2233.333333
# marks       1789.813333
# packages    3172.000000
# dtype: float64

# %% [markdown]
# # Selecting column from a data frame

# %%
# single cols
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: str

# %%
# multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
ipl[['Team1','Team2','WinningTeam','Date']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam        Date
# 0                 Gujarat Titans  2022-05-29
# 1               Rajasthan Royals  2022-05-27
# 2    Royal Challengers Bangalore  2022-05-25
# ...

# %% [markdown]
# ### Selecting Row

# %%
student_data = {
    'name' : ['nitish','ankit','rishabh'],
   'iq': [100,80,10],
    'marks' :[90,70,8.8],
    'packages' :[120,100,14],\

}
students = pd.DataFrame(student_data)
students.set_index('name',inplace=True)
students
# Out:
#           iq  marks  packages
# name
# nitish   100   90.0       120
# ankit     80   70.0       100
# rishabh   10    8.8        14

# %% [markdown]
# ### Selectinng rows using from a Data Frame
#   . iloc - searches using index positions
#
#   . loc - searches using index labels

# %%
# single row
movies.iloc[100]
# Out:
# title_x                                           October (2018 film)
# imdb_id                                                     tt7700730
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/October_(2018_film)
# title_y                                                       October
# original_title                                                October
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           115
# genres                                                  Drama|Romance
# imdb_rating                                                       7.5
# imdb_votes                                                      11125
# story               Dan (Varun Dhawan) is living the life of any c...
# ...

# %%
# mulitple 
movies.iloc[0:50:5]
# Out:
#                       title_x     imdb_id  \
# 0    Uri: The Surgical Strike   tt8291224
# 5                 Soni (film)   tt6078866
# 10                     Amavas   tt8396186
# 15          Badla (2019 film)   tt8130968
# 20  Mere Pyare Prime Minister   tt8207768
# 25                  Gone Kesh  tt10017956
# 30      Student of the Year 2   tt7255568
# 35       Khamoshi (2019 film)   tt8268972
# 40            Super 30 (film)   tt7485048
# 45          Chicken Curry Law   tt7189494
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
# 20  https://upload.wikimedia.org/wikipedia/en/thum...
# 25  https://upload.wikimedia.org/wikipedia/en/thum...
# 30  https://upload.wikimedia.org/wikipedia/en/thum...
# 35  https://upload.wikimedia.org/wikipedia/en/e/ef...
# ...

# %%
#  fancing indexing
movies.iloc[[4,7,10,34,76]]
# Out:
#               title_x    imdb_id  \
# 4     Evening Shadows  tt6028796
# 7          Bombairiya  tt4971258
# 10             Amavas  tt8396186
# 34      Yeh Hai India  tt5525846
# 76  Commando 3 (film)  tt8983168
#
#                                           poster_path  \
# 4                                                 NaN
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 76  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 4     https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 7          https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
# 10             https://en.wikipedia.org/wiki/Amavas           Amavas
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India    Yeh Hai India
# 76  https://en.wikipedia.org/wiki/Commando_3_(film)       Commando 3
#
# ...

# %%
#  loc 
students
# Out:
#           iq  marks  packages
# name
# nitish   100   90.0       120
# ankit     80   70.0       100
# rishabh   10    8.8        14

# %%
students.loc['nitish']
students.loc['nitish':'rishabh']
students.loc[['nitish','rishabh','ankit']]
# Out:
#           iq  marks  packages
# name
# nitish   100   90.0       120
# rishabh   10    8.8        14
# ankit     80   70.0       100

# %%
#  rows and  columns
# movies.iloc[rows,column]
movies.iloc[[2,6,8,15],[1,5,8]]
# Out:
#       imdb_id                    original_title runtime
# 2   tt6986710     The Accidental Prime Minister     112
# 6   tt5013008                     Fraud Saiyyan     109
# 8   tt6903440  Manikarnika: The Queen of Jhansi     148
# 15  tt8130968                             Badla     118

# %% [markdown]
# # filtering

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find all the final winners
mask = ipl['MatchNumber'] == 'Final'
new_def = ipl[mask]
new_def[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals
