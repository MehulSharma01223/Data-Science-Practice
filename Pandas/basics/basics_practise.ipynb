# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C", "D"],
    "Age": [20, 21, 22, 23],
    "Marks": [50, 60, 70, 80]
}

df = pd.DataFrame(data)

# TASK:
# 1. Add column "Result" (Marks > 60)
# 2. Increase Marks by 10
# 3. Print only Name and Result
# 4. Print shapeimport pandas as pd

data = {
    "Name": ["A", "B", "C", "D"],
    "Age": [20, 21, 22, 23],
    "Marks": [50, 60, 70, 80]
}

df = pd.DataFrame(data)

# TASK:
# 1. Add column "Result" (Marks > 60)
# 2. Increase Marks by 10
# 3. Print only Name and Result
# 4. Print shape

# %%
df["Result"] = df["Marks"]> 60
print(df)
df["Marks"] = df["Marks"] + 10
print(df["Marks"])
print(df[["Name","Result"]])
print(df.shape)
# Out:
#   Name  Age  Marks  Result
# 0    A   20     60   False
# 1    B   21     70    True
# 2    C   22     80    True
# 3    D   23     90    True
# 0     70
# 1     80
# 2     90
# 3    100
# Name: Marks, dtype: int64
#   Name  Result
# 0    A   False
# 1    B    True
# 2    C    True
# 3    D    True
# (4, 4)
